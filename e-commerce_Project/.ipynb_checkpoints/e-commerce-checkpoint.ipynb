# %% [markdown]
# <p style="background-color:firebrick;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>EDA Project</b></p>

# %% [markdown]
# <b>Contains:</b>
# <ul>
# <li><a href="#import-library">Importing Libraries</a></li>
# <li><a href="#loading-dataset">Loading The Dataset</a></li>
# <li><a href="#understanding-dataset">Understanding The Dataset</a></li>
# <li><a href="#organizing-columns">Organizing Columns</a></li>
# <li><a href="#nan-values">NaN Values</a></li>
# <li><a href="#data-visualization">Data Visualization</a></li>
# <li><a href="#save-data">Save  to Dataset</a></li>
# </ul>

# %% [markdown]
# <a id='import-library'></a>
# # <font color='firebrick'> <b>Importing Libraries</b><font color='black'>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

import missingno as msno
import plotly.express as px

from skimpy import skim

import warnings
warnings.filterwarnings("ignore")

pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %% [markdown]
# <a id='loading-dataset'></a>
# # <font color='firebrick'> <b>Loading The Dataset</b><font color='black'>

# %%
df0 = pd.read_csv("realistic_e_commerce_sales_data.csv")
df = df0.copy()

# %%
df.sample(5)
# Out:
#     Customer ID  Gender Region   Age Product Name     Category  Unit Price  \
# 229    CUST0188    Male   West  29.0      Monitor  Electronics       300.0
# 286    CUST0129    Male  South  66.0        Mouse  Accessories        30.0
# 985    CUST0068  Female  North  64.0     Keyboard  Accessories        50.0
# 767    CUST0215  Female   East  35.0        Mouse  Accessories        30.0
# 100    CUST0024  Female   East  57.0   Smartwatch    Wearables       200.0
#
#      Quantity  Total Price  Shipping Fee Shipping Status  Order Date
# 229         4         1200          8.15       Delivered  2023-07-26
# 286         2           60          9.19      In Transit  2023-05-07
# 985         5          250         13.30        Returned  2023-07-02
# 767         3           90          8.79        Returned  2023-07-29
# 100         2          400         17.94      In Transit  2023-12-08

# %% [markdown]
# <a id='understanding-dataset'></a>
# # <font color='firebrick'> <b>Understanding The Dataset</b><font color='black'>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Customer ID      1000 non-null   object
#  1   Gender           1000 non-null   object
#  2   Region           950 non-null    object
#  3   Age              900 non-null    float64
#  4   Product Name     1000 non-null   object
#  5   Category         1000 non-null   object
#  6   Unit Price       1000 non-null   float64
#  7   Quantity         1000 non-null   int64
#  8   Total Price      1000 non-null   int64
#  9   Shipping Fee     1000 non-null   float64
#  10  Shipping Status  950 non-null    object
#  11  Order Date       1000 non-null   object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 93.9+ KB

# %%
df.describe().T
# Out:
#                count         mean          std   min     25%      50%  \
# Age            900.0    46.695556    15.011400  18.0   35.00   49.000
# Unit Price    1000.0   457.703777   537.231434  30.0   50.00  200.000
# Quantity      1000.0     3.008000     1.404246   1.0    2.00    3.000
# Total Price   1000.0  1346.600000  1834.037877  30.0  200.00  600.000
# Shipping Fee  1000.0    12.416390     4.412185   5.0    8.56   12.315
#
#                    75%          max
# Age             59.000    69.000000
# Unit Price     800.000  3109.560612
# Quantity         4.000     5.000000
# Total Price   1500.000  7500.000000
# Shipping Fee    16.075    19.980000

# %%
df.describe(include = 'object').T
# Out:
#                 count unique          top freq
# Customer ID      1000    292     CUST0204    9
# Gender           1000      2         Male  524
# Region            950      4         West  246
# Product Name     1000      7      Monitor  181
# Category         1000      3  Electronics  477
# Shipping Status   950      3   In Transit  329
# Order Date       1000    340   2024-01-03   20

# %%
df.isnull().sum()
# Out:
# Customer ID          0
# Gender               0
# Region              50
# Age                100
# Product Name         0
# Category             0
# Unit Price           0
# Quantity             0
# Total Price          0
# Shipping Fee         0
# Shipping Status     50
# Order Date           0
# dtype: int64

# %%
skim(df)
# Out:
# ╭──────────────────────────────────────────────── skimpy summary ─────────────────────────────────────────────────╮
# │          Data Summary                Data Types                                                                 │
# │ ┏━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┓ ┏━━━━━━━━━━━━━┳━━━━━━━┓                                                          │
# │ ┃ dataframe         ┃ Values ┃ ┃ Column Type ┃ Count ┃                                                          │
# │ ┡━━━━━━━━━━━━━━━━━━━╇━━━━━━━━┩ ┡━━━━━━━━━━━━━╇━━━━━━━┩                                                          │
# │ │ Number of rows    │ 1000   │ │ string      │ 7     │                                                          │
# │ │ Number of columns │ 12     │ │ float64     │ 3     │                                                          │
# │ └───────────────────┴────────┘ │ int32       │ 2     │                                                          │
# │                                └─────────────┴───────┘                                                          │
# │                                                     number                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━┳━━━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━━┳━━━━━┳━━━━━━━━┳━━━━━━━━━┳━━━━━━━━┳━━━━━━━━┳━━━━━━━━━┓  │
# │ ┃ column_name      ┃ NA    ┃ NA %   ┃ mean    ┃ sd      ┃ p0  ┃ p25    ┃ p50     ┃ p75    ┃ p100   ┃ hist    ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━╇━━━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━━╇━━━━━╇━━━━━━━━╇━━━━━━━━━╇━━━━━━━━╇━━━━━━━━╇━━━━━━━━━┩  │
# │ │ Age              │   100 │     10 │    46.7 │   15.01 │  18 │     35 │      49 │     59 │     69 │ ▅▅▆▅▇▇  │  │
# │ │ Unit Price       │     0 │      0 │   457.7 │   537.2 │  30 │     50 │     200 │    800 │   3110 │   ▇▂▂   │  │
# │ │ Quantity         │     0 │      0 │   3.008 │   1.404 │   1 │      2 │       3 │      4 │      5 │ ▇▇ ▇▇▇  │  │
# │ │ Total Price      │     0 │      0 │    1347 │    1834 │  30 │    200 │     600 │   1500 │   7500 │  ▇▁▁▁   │  │
# │ │ Shipping Fee     │     0 │      0 │   12.42 │   4.412 │   5 │   8.56 │   12.32 │  16.07 │  19.98 │ ▇▇▇▇▆▇  │  │
# │ └──────────────────┴───────┴────────┴─────────┴─────────┴─────┴────────┴─────────┴────────┴────────┴─────────┘  │
# │                                                     string                                                      │
# │ ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┓  │
# │ ┃ column_name                     ┃ NA     ┃ NA %       ┃ words per row              ┃ total words           ┃  │
# │ ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━┩  │
# │ │ Customer ID                     │      0 │          0 │                          1 │                  1000 │  │
# │ │ Gender                          │      0 │          0 │                          1 │                  1000 │  │
# │ │ Region                          │     50 │          5 │                       0.95 │                   950 │  │
# │ │ Product Name                    │      0 │          0 │                          1 │                  1000 │  │
# │ │ Category                        │      0 │          0 │                          1 │                  1000 │  │
# │ │ Shipping Status                 │     50 │          5 │                        1.3 │                  1279 │  │
# │ │ Order Date                      │      0 │          0 │                          1 │                  1000 │  │
# │ └─────────────────────────────────┴────────┴────────────┴────────────────────────────┴───────────────────────┘  │
# ╰────────────────────────────────────────────────────── End ──────────────────────────────────────────────────────╯

# %%
msno.matrix(df)
# Out:
# <Axes: >

# %% [markdown]
# <a id='organizing-columns'></a>
# # <font color='firebrick'> <b>Organizing Columns</b><font color='black'>

# %%
df.columns
# Out:
# Index(['Customer ID', 'Gender', 'Region', 'Age', 'Product Name', 'Category',
#        'Unit Price', 'Quantity', 'Total Price', 'Shipping Fee',
#        'Shipping Status', 'Order Date'],
#       dtype='object')

# %%
df.columns=df.columns.str.replace(" ","_").str.lower()
df.columns
# Out:
# Index(['customer_id', 'gender', 'region', 'age', 'product_name', 'category',
#        'unit_price', 'quantity', 'total_price', 'shipping_fee',
#        'shipping_status', 'order_date'],
#       dtype='object')

# %%
df.shape
# Out:
# (1000, 12)

# %%
df.duplicated().sum()
# Out:
# 0

# %% [markdown]
# ## <font color='orange'> <b> Customer ID </b><font color='black'>

# %%
df.customer_id.nunique()
# Out:
# 292

# %% [markdown]
# ## <font color='orange'> <b> Gender </b><font color='black'>

# %%
df.gender.nunique()
# Out:
# 2

# %% [markdown]
# ## <font color='orange'> <b> Shipping Status </b><font color='black'>

# %%
df.shipping_status.nunique()
# Out:
# 3

# %% [markdown]
# ## <font color='orange'> <b> Age </b><font color='black'>

# %%
df.age.nunique()
# Out:
# 52

# %%
df.age.unique()
# Out:
# array([nan, 22., 54., 23., 64., 27., 18., 29., 49., 67., 41., 60., 66.,
#        36., 57., 30., 32., 59., 37., 52., 58., 25., 31., 28., 53., 35.,
#        43., 61., 19., 38., 44., 68., 42., 51., 46., 62., 33., 24., 21.,
#        50., 48., 63., 47., 45., 40., 55., 69., 26., 20., 65., 39., 56.,
#        34.])

# %% [markdown]
# ## <font color='orange'> <b> Category </b><font color='black'>

# %%
df.category.unique()
# Out:
# array(['Electronics', 'Accessories', 'Wearables'], dtype=object)

# %% [markdown]
# ## <font color='orange'> <b> Unit Price </b><font color='black'>

# %%
df.unit_price.nunique()
# Out:
# 13

# %%
df.unit_price.unique()
# Out:
# array([ 300.        ,  100.        , 1500.        ,  200.        ,
#          50.        ,   30.        ,  800.        , 1658.43232666,
#          62.19121225,  103.65202042,  621.9121225 ,  207.30404083,
#        3109.56061249])

# %%
df.unit_price = round(df.unit_price,2)

# %%
df.unit_price.nunique()
# Out:
# 13

# %% [markdown]
# ## <font color='orange'> <b> Quantity </b><font color='black'>

# %%
df.quantity.nunique()
# Out:
# 5

# %%
df.quantity.unique()
# Out:
# array([5, 2, 1, 3, 4], dtype=int64)

# %% [markdown]
# ## <font color='orange'> <b> Shipping Fee </b><font color='black'>

# %%
df.shipping_fee.nunique()
# Out:
# 730

# %% [markdown]
# ## <font color='orange'> <b> Shipping Status </b><font color='black'>

# %%
df.shipping_status.nunique()
# Out:
# 3

# %%
df.shipping_status.unique()
# Out:
# array(['Returned', 'In Transit', 'Delivered', nan], dtype=object)

# %% [markdown]
# ## <font color='orange'> <b> Order Date </b><font color='black'>

# %%
df.order_date.nunique()
# Out:
# 340

# %%
df.order_date.dtype
# Out:
# dtype('O')

# %%
df['order_date'] = pd.to_datetime(df['order_date'])

# %% [markdown]
# <a id='nan-values'></a>
# # <font color='firebrick'> <b>NaN Values</b><font color='black'>

# %%
df.isnull().sum()
# Out:
# customer_id          0
# gender               0
# region              50
# age                100
# product_name         0
# category             0
# unit_price           0
# quantity             0
# total_price          0
# shipping_fee         0
# shipping_status     50
# order_date           0
# dtype: int64

# %%
df.groupby(["product_name","region"])[["category"]].count()
# Out:
#                      category
# product_name region
# Headphones   East          35
#              North         26
#              South         25
#              West          28
# Keyboard     East          25
#              North         33
#              South         38
#              West          42
# Laptop       East          35
#              North         39
#              South         32
#              West          41
# Monitor      East          40
#              North         43
#              South         52
#              West          42
# Mouse        East          29
#              North         30
#              South         33
#              West          35
# Smartphone   East          33
#              North         31
#              South         35
#              West          33
# Smartwatch   East          34
#              North         27
#              South         29
#              West          25

# %%
 df.groupby('product_name')['region'].apply(lambda x: x.mode()[0])
# Out:
# product_name
# Headphones     East
# Keyboard       West
# Laptop         West
# Monitor       South
# Mouse          West
# Smartphone    South
# Smartwatch     East
# Name: region, dtype: object

# %%
df['region'] = df['region'].fillna(df['product_name'].map( df.groupby('product_name')['region'].apply(lambda x: x.mode()[0])))

# %%
df.isnull().sum()
# Out:
# customer_id          0
# gender               0
# region               0
# age                100
# product_name         0
# category             0
# unit_price           0
# quantity             0
# total_price          0
# shipping_fee         0
# shipping_status     50
# order_date           0
# dtype: int64

# %%
df.region.describe()
# Out:
# count     1000
# unique       4
# top       West
# freq       269
# Name: region, dtype: object

# %%
df.sample(5)
# Out:
#     customer_id  gender region   age product_name     category  unit_price  \
# 753    CUST0201  Female  North  49.0   Smartwatch    Wearables       200.0
# 481    CUST0196  Female   West  37.0       Laptop  Electronics      1500.0
# 653    CUST0133    Male   West  47.0   Smartwatch    Wearables       200.0
# 326    CUST0031  Female   East  67.0   Smartphone  Electronics       800.0
# 420    CUST0069  Female   East  66.0       Laptop  Electronics      1500.0
#
#      quantity  total_price  shipping_fee shipping_status order_date
# 753         3          600          9.26       Delivered 2023-10-23
# 481         1         1500         12.95        Returned 2023-11-06
# 653         3          600         13.73       Delivered 2023-06-15
# 326         5         4000          9.60      In Transit 2023-10-22
# 420         4         6000         16.92      In Transit 2023-09-23

# %%
df.groupby(["customer_id","shipping_status"])[["customer_id"]].count()
# Out:
#                              customer_id
# customer_id shipping_status
# CUST0001    Returned                   2
# CUST0002    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0003    Delivered                  1
#             In Transit                 2
# CUST0004    In Transit                 2
#             Returned                   2
# CUST0005    In Transit                 1
# CUST0006    Delivered                  3
#             In Transit                 3
# CUST0007    Delivered                  1
#             In Transit                 2
# CUST0008    Delivered                  2
#             In Transit                 2
# CUST0010    Delivered                  3
#             In Transit                 2
#             Returned                   1
# CUST0011    Delivered                  2
#             In Transit                 1
#             Returned                   1
# CUST0012    Delivered                  2
#             In Transit                 1
#             Returned                   2
# CUST0013    Returned                   1
# CUST0014    Returned                   1
# CUST0015    Returned                   1
# CUST0016    Delivered                  3
#             In Transit                 2
# CUST0017    Delivered                  1
# CUST0018    Delivered                  1
#             In Transit                 2
# CUST0019    Delivered                  2
#             In Transit                 1
#             Returned                   1
# CUST0020    Delivered                  1
#             Returned                   1
# CUST0021    In Transit                 1
# CUST0022    Delivered                  3
#             Returned                   2
# CUST0023    Delivered                  2
#             In Transit                 1
#             Returned                   2
# CUST0024    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0025    In Transit                 1
#             Returned                   2
# CUST0026    In Transit                 1
#             Returned                   1
# CUST0027    Returned                   2
# CUST0028    Delivered                  4
#             In Transit                 3
# CUST0029    In Transit                 2
# CUST0030    In Transit                 1
#             Returned                   1
# CUST0031    Delivered                  2
#             In Transit                 3
#             Returned                   1
# CUST0032    Delivered                  1
#             In Transit                 1
#             Returned                   2
# CUST0033    Delivered                  1
# CUST0034    Delivered                  1
#             Returned                   1
# CUST0035    Returned                   2
# CUST0036    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0037    In Transit                 1
#             Returned                   1
# CUST0038    In Transit                 2
#             Returned                   2
# CUST0039    In Transit                 2
#             Returned                   1
# CUST0040    Delivered                  1
#             Returned                   1
# CUST0041    In Transit                 1
#             Returned                   1
# CUST0042    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0043    Delivered                  2
#             In Transit                 1
# CUST0044    Delivered                  3
#             In Transit                 3
#             Returned                   3
# CUST0045    Delivered                  2
#             In Transit                 2
# CUST0046    Delivered                  2
#             In Transit                 1
#             Returned                   2
# CUST0047    Returned                   3
# CUST0048    In Transit                 2
#             Returned                   1
# CUST0049    In Transit                 1
#             Returned                   1
# CUST0050    Delivered                  1
#             Returned                   1
# CUST0051    Delivered                  1
#             Returned                   1
# CUST0052    Delivered                  2
#             In Transit                 4
#             Returned                   2
# CUST0053    Delivered                  1
#             In Transit                 2
#             Returned                   2
# CUST0054    Delivered                  2
#             In Transit                 1
# CUST0055    Delivered                  1
#             Returned                   4
# CUST0056    Returned                   1
# CUST0057    Delivered                  1
# CUST0058    Delivered                  3
#             In Transit                 2
#             Returned                   1
# CUST0059    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0060    Delivered                  4
#             Returned                   1
# CUST0061    In Transit                 1
#             Returned                   1
# CUST0062    Delivered                  1
#             Returned                   2
# CUST0063    Delivered                  2
#             In Transit                 1
#             Returned                   1
# CUST0064    Delivered                  1
#             In Transit                 1
#             Returned                   5
# CUST0065    Delivered                  2
#             In Transit                 2
#             Returned                   1
# CUST0066    Delivered                  1
#             In Transit                 2
#             Returned                   3
# CUST0067    Delivered                  1
# CUST0068    In Transit                 2
#             Returned                   2
# CUST0069    In Transit                 3
#             Returned                   1
# CUST0070    Delivered                  1
#             Returned                   1
# CUST0071    Delivered                  1
#             In Transit                 3
#             Returned                   2
# CUST0072    Delivered                  1
#             In Transit                 1
# CUST0073    Delivered                  1
#             In Transit                 2
# CUST0074    Returned                   1
# CUST0075    Delivered                  1
#             In Transit                 1
# CUST0076    Delivered                  3
#             Returned                   1
# CUST0077    Delivered                  2
#             In Transit                 1
#             Returned                   1
# CUST0078    Delivered                  1
#             In Transit                 1
#             Returned                   2
# CUST0079    In Transit                 2
#             Returned                   1
# CUST0080    Delivered                  2
#             Returned                   1
# CUST0081    Delivered                  1
#             In Transit                 1
#             Returned                   3
# CUST0082    Delivered                  2
#             Returned                   1
# CUST0083    Returned                   2
# CUST0085    Delivered                  2
#             Returned                   1
# CUST0086    Delivered                  1
# CUST0087    Delivered                  1
#             In Transit                 1
# CUST0088    Delivered                  1
#             In Transit                 3
# CUST0089    In Transit                 2
# CUST0090    Delivered                  1
# CUST0091    Delivered                  3
#             In Transit                 2
#             Returned                   1
# CUST0092    Delivered                  1
#             In Transit                 1
# CUST0093    Delivered                  2
# CUST0094    Delivered                  1
#             In Transit                 1
# CUST0095    Delivered                  3
#             In Transit                 4
#             Returned                   2
# CUST0096    In Transit                 1
# CUST0097    Returned                   2
# CUST0098    In Transit                 1
# CUST0099    In Transit                 1
#             Returned                   1
# CUST0100    Returned                   1
# CUST0101    Delivered                  1
#             In Transit                 1
# CUST0102    Delivered                  1
# CUST0103    Delivered                  1
#             In Transit                 2
#             Returned                   1
# CUST0104    Delivered                  2
#             In Transit                 1
# CUST0105    In Transit                 4
#             Returned                   2
# CUST0106    Delivered                  2
#             In Transit                 2
#             Returned                   1
# CUST0107    Delivered                  1
#             Returned                   2
# CUST0108    Delivered                  1
#             Returned                   1
# CUST0109    Delivered                  2
#             In Transit                 2
#             Returned                   1
# CUST0111    In Transit                 1
# CUST0112    Delivered                  2
#             Returned                   2
# CUST0113    Delivered                  1
#             In Transit                 1
#             Returned                   2
# CUST0114    In Transit                 3
# CUST0115    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0116    Delivered                  1
#             In Transit                 1
#             Returned                   2
# CUST0117    Delivered                  1
#             Returned                   1
# CUST0118    Delivered                  1
#             In Transit                 2
#             Returned                   1
# CUST0120    Delivered                  1
#             In Transit                 1
# CUST0121    Returned                   2
# CUST0122    Delivered                  1
#             In Transit                 1
#             Returned                   2
# CUST0123    In Transit                 2
# CUST0124    Delivered                  1
#             In Transit                 2
#             Returned                   3
# CUST0125    Delivered                  1
#             In Transit                 1
#             Returned                   2
# CUST0126    Delivered                  1
#             In Transit                 2
#             Returned                   2
# CUST0127    Delivered                  2
#             In Transit                 1
# CUST0128    Delivered                  3
#             In Transit                 1
#             Returned                   1
# CUST0129    Delivered                  3
#             In Transit                 2
# CUST0130    Delivered                  1
#             In Transit                 1
#             Returned                   2
# CUST0131    Delivered                  3
#             In Transit                 3
# CUST0133    Delivered                  4
#             In Transit                 2
#             Returned                   1
# CUST0134    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0135    In Transit                 1
# CUST0136    In Transit                 1
#             Returned                   2
# CUST0137    Delivered                  2
#             In Transit                 1
#             Returned                   2
# CUST0138    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0139    Delivered                  2
#             In Transit                 2
#             Returned                   2
# CUST0140    Delivered                  2
#             Returned                   1
# CUST0141    Delivered                  1
#             In Transit                 1
# CUST0142    Delivered                  1
#             In Transit                 4
#             Returned                   2
# CUST0143    Delivered                  1
# CUST0144    Delivered                  2
#             In Transit                 1
#             Returned                   2
# CUST0145    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0146    Delivered                  1
# CUST0147    In Transit                 1
# CUST0148    Delivered                  2
#             In Transit                 2
#             Returned                   1
# CUST0149    Delivered                  1
#             In Transit                 2
#             Returned                   2
# CUST0150    Delivered                  3
#             Returned                   1
# CUST0152    Delivered                  1
#             In Transit                 3
#             Returned                   2
# CUST0153    Delivered                  1
#             Returned                   2
# CUST0154    Delivered                  1
#             In Transit                 2
#             Returned                   1
# CUST0155    Delivered                  2
#             In Transit                 1
#             Returned                   1
# CUST0156    In Transit                 2
#             Returned                   2
# CUST0157    In Transit                 1
# CUST0158    In Transit                 1
#             Returned                   1
# CUST0159    Delivered                  1
#             In Transit                 1
#             Returned                   4
# CUST0160    Delivered                  2
#             In Transit                 1
#             Returned                   2
# CUST0161    Returned                   1
# CUST0162    In Transit                 1
#             Returned                   2
# CUST0163    Returned                   1
# CUST0164    In Transit                 1
# CUST0165    Returned                   1
# CUST0166    Returned                   1
# CUST0167    Delivered                  1
#             Returned                   1
# CUST0168    Delivered                  2
#             In Transit                 3
# CUST0169    Returned                   1
# CUST0170    Delivered                  2
# CUST0171    In Transit                 1
# CUST0172    In Transit                 1
#             Returned                   1
# CUST0173    Delivered                  2
#             In Transit                 1
#             Returned                   1
# CUST0174    Delivered                  2
#             In Transit                 2
#             Returned                   2
# CUST0176    Delivered                  2
#             In Transit                 3
# CUST0177    Delivered                  1
#             In Transit                 2
# CUST0178    Delivered                  2
#             In Transit                 2
# CUST0179    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0180    Delivered                  1
#             In Transit                 1
# CUST0181    In Transit                 2
# CUST0182    Delivered                  2
#             In Transit                 2
#             Returned                   1
# CUST0183    Delivered                  2
#             Returned                   1
# CUST0184    In Transit                 1
#             Returned                   2
# CUST0185    Delivered                  2
#             In Transit                 1
# CUST0186    Delivered                  1
#             In Transit                 2
#             Returned                   2
# CUST0187    Delivered                  2
# CUST0188    Delivered                  2
#             Returned                   1
# CUST0189    Delivered                  2
#             In Transit                 1
#             Returned                   1
# CUST0190    Delivered                  1
# CUST0192    Delivered                  1
#             In Transit                 2
# CUST0193    Delivered                  2
#             In Transit                 2
# CUST0194    In Transit                 1
#             Returned                   1
# CUST0195    In Transit                 2
#             Returned                   1
# CUST0196    Delivered                  4
#             Returned                   3
# CUST0197    Delivered                  3
#             In Transit                 2
# CUST0198    Delivered                  1
#             In Transit                 1
#             Returned                   2
# CUST0199    Delivered                  2
#             In Transit                 1
#             Returned                   3
# CUST0200    Delivered                  1
#             Returned                   3
# CUST0201    Delivered                  3
#             In Transit                 3
#             Returned                   2
# CUST0202    Delivered                  2
#             In Transit                 2
# CUST0203    In Transit                 3
#             Returned                   2
# CUST0204    Delivered                  5
#             Returned                   4
# CUST0205    Delivered                  1
#             In Transit                 1
# CUST0206    In Transit                 2
# CUST0207    Delivered                  1
#             Returned                   1
# CUST0208    Delivered                  2
#             In Transit                 1
#             Returned                   1
# CUST0209    Delivered                  1
# CUST0210    Returned                   3
# CUST0211    Delivered                  1
#             In Transit                 1
#             Returned                   2
# CUST0212    Delivered                  1
#             In Transit                 3
# CUST0213    Delivered                  1
#             In Transit                 1
# CUST0214    In Transit                 1
# CUST0215    Delivered                  1
#             Returned                   1
# CUST0216    In Transit                 1
#             Returned                   4
# CUST0218    In Transit                 3
#             Returned                   2
# CUST0219    Delivered                  2
#             In Transit                 1
#             Returned                   1
# CUST0220    In Transit                 1
#             Returned                   3
# CUST0221    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0222    Delivered                  1
#             Returned                   1
# CUST0223    In Transit                 1
#             Returned                   1
# CUST0224    Delivered                  2
# CUST0225    Delivered                  2
#             In Transit                 1
#             Returned                   1
# CUST0226    In Transit                 1
#             Returned                   2
# CUST0227    In Transit                 3
#             Returned                   1
# CUST0228    In Transit                 5
#             Returned                   1
# CUST0229    Delivered                  4
# CUST0230    In Transit                 1
# CUST0231    In Transit                 1
#             Returned                   1
# CUST0232    In Transit                 2
#             Returned                   2
# CUST0233    In Transit                 1
# CUST0234    Returned                   2
# CUST0235    In Transit                 2
# CUST0236    Delivered                  1
#             Returned                   2
# CUST0237    In Transit                 1
# CUST0238    Delivered                  2
#             In Transit                 1
#             Returned                   1
# CUST0239    Delivered                  3
#             In Transit                 1
# CUST0240    Delivered                  3
#             In Transit                 1
#             Returned                   1
# CUST0241    Delivered                  1
#             In Transit                 2
# CUST0242    In Transit                 1
#             Returned                   1
# CUST0243    Returned                   1
# CUST0244    In Transit                 1
# CUST0245    Delivered                  1
#             Returned                   2
# CUST0246    Delivered                  1
# CUST0247    Delivered                  1
#             In Transit                 3
# CUST0248    Delivered                  1
#             Returned                   1
# CUST0249    In Transit                 1
# CUST0250    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0251    In Transit                 2
# CUST0252    Delivered                  1
#             Returned                   1
# CUST0253    Delivered                  1
#             In Transit                 3
#             Returned                   2
# CUST0254    Delivered                  1
# CUST0255    Delivered                  2
#             Returned                   1
# CUST0256    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0257    In Transit                 1
# CUST0258    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0259    Delivered                  2
#             In Transit                 1
# CUST0260    Delivered                  1
#             Returned                   1
# CUST0261    Delivered                  1
#             Returned                   1
# CUST0262    In Transit                 1
#             Returned                   1
# CUST0263    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0264    Delivered                  3
#             In Transit                 2
#             Returned                   1
# CUST0265    In Transit                 1
#             Returned                   1
# CUST0266    Delivered                  1
#             In Transit                 1
#             Returned                   1
# CUST0267    Returned                   1
# CUST0268    Delivered                  1
#             In Transit                 2
#             Returned                   2
# CUST0269    Delivered                  1
#             Returned                   3
# CUST0270    Delivered                  2
#             Returned                   2
# CUST0271    In Transit                 4
#             Returned                   1
# CUST0272    Delivered                  2
#             In Transit                 2
#             Returned                   1
# CUST0273    In Transit                 3
#             Returned                   1
# CUST0274    Delivered                  1
#             In Transit                 1
#             Returned                   2
# CUST0276    Delivered                  4
#             In Transit                 3
# CUST0278    In Transit                 1
# CUST0279    Delivered                  1
#             Returned                   3
# CUST0280    Delivered                  1
#             In Transit                 1
# CUST0281    Delivered                  2
#             In Transit                 4
#             Returned                   2
# CUST0282    Delivered                  2
#             In Transit                 1
#             Returned                   1
# CUST0283    Delivered                  1
#             In Transit                 3
# CUST0284    In Transit                 4
#             Returned                   1
# CUST0285    Delivered                  2
#             In Transit                 1
# CUST0286    Delivered                  1
#             Returned                   1
# CUST0287    Returned                   1
# CUST0288    Delivered                  2
#             Returned                   3
# CUST0289    Delivered                  1
#             Returned                   2
# CUST0290    In Transit                 1
#             Returned                   2
# CUST0291    Delivered                  3
#             In Transit                 1
# CUST0292    Delivered                  1
# CUST0293    Delivered                  1
#             In Transit                 2
#             Returned                   2
# CUST0294    In Transit                 1
# CUST0295    In Transit                 2
#             Returned                   1
# CUST0296    Delivered                  1
#             In Transit                 2
#             Returned                   3
# CUST0297    In Transit                 1
#             Returned                   1
# CUST0298    Delivered                  1
#             Returned                   2
# CUST0299    Delivered                  1
#             In Transit                 1
#             Returned                   5
# CUST0300    In Transit                 1
#             Returned                   1

# %%
df['shipping_status'] = df['shipping_status'].fillna(df['customer_id'].map(df.groupby('customer_id')['shipping_status'].apply(lambda x: x.mode()[0] if not x.mode().empty else None)))

# %%
df.isnull().sum()
# Out:
# customer_id          0
# gender               0
# region               0
# age                100
# product_name         0
# category             0
# unit_price           0
# quantity             0
# total_price          0
# shipping_fee         0
# shipping_status      3
# order_date           0
# dtype: int64

# %%
df['shipping_status'] = df['shipping_status'].fillna(df['shipping_status'].mode()[0])

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      1000 non-null   object
#  1   gender           1000 non-null   object
#  2   region           1000 non-null   object
#  3   age              900 non-null    float64
#  4   product_name     1000 non-null   object
#  5   category         1000 non-null   object
#  6   unit_price       1000 non-null   float64
#  7   quantity         1000 non-null   int64
#  8   total_price      1000 non-null   int64
#  9   shipping_fee     1000 non-null   float64
#  10  shipping_status  1000 non-null   object
#  11  order_date       1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(2), object(6)
# memory usage: 93.9+ KB

# %%
df['shipping_status'].fillna(df['customer_id'].map(df.groupby('customer_id')['shipping_status'].apply(lambda x: x.mode()[0] if not x.mode().empty else None)))

# %%
df.groupby(['customer_id','age'])[['age']].sorted_values()
# Out:
# customer_id
# CUST0001    38.0
# CUST0002    23.0
# CUST0003    63.0
# CUST0004    65.0
# CUST0005    56.0
# CUST0006    52.0
# CUST0007    52.0
# CUST0008    18.0
# CUST0009    50.0
# CUST0010    37.0
# CUST0011    54.0
# CUST0012    28.0
# CUST0013    55.0
# CUST0014    20.0
# CUST0015    58.0
# CUST0016    61.0
# CUST0017    36.0
# CUST0018    38.0
# CUST0019    69.0
# CUST0020    55.0
# CUST0021    43.0
# CUST0022    33.0
# CUST0023    29.0
# CUST0024    57.0
# CUST0025    56.0
# CUST0026    27.0
# CUST0027    36.0
# CUST0028    50.0
# CUST0029    66.0
# CUST0030    44.0
# CUST0031    67.0
# CUST0032    63.0
# CUST0033     NaN
# CUST0034    65.0
# CUST0035    20.0
# CUST0036    33.0
# CUST0037    51.0
# CUST0038    57.0
# CUST0039    60.0
# CUST0040    29.0
# CUST0041    64.0
# CUST0042    57.0
# CUST0043    22.0
# CUST0044    30.0
# CUST0045    21.0
# CUST0046    22.0
# CUST0047    41.0
# CUST0048    34.0
# CUST0049    59.0
# CUST0050    40.0
# CUST0051    41.0
# CUST0052    66.0
# CUST0053    25.0
# CUST0054    64.0
# CUST0055    45.0
# CUST0056    23.0
# CUST0057    62.0
# CUST0058    42.0
# CUST0059    18.0
# CUST0060    41.0
# CUST0061    35.0
# CUST0062    43.0
# CUST0063    20.0
# CUST0064    61.0
# CUST0065    41.0
# CUST0066    37.0
# CUST0067    19.0
# CUST0068    64.0
# CUST0069    66.0
# CUST0070    23.0
# CUST0071    46.0
# CUST0072    21.0
# CUST0073    19.0
# CUST0074    36.0
# CUST0075    56.0
# CUST0076    26.0
# CUST0077    50.0
# CUST0078    38.0
# CUST0079    26.0
# CUST0080    51.0
# CUST0081    38.0
# CUST0082    30.0
# CUST0083    28.0
# CUST0085    18.0
# CUST0086    26.0
# CUST0087    49.0
# CUST0088    66.0
# CUST0089    27.0
# CUST0090    61.0
# CUST0091    30.0
# CUST0092    32.0
# CUST0093    66.0
# CUST0094    30.0
# CUST0095    60.0
# CUST0096    61.0
# CUST0097    34.0
# CUST0098    57.0
# CUST0099    26.0
# CUST0100    29.0
# CUST0101    53.0
# CUST0102    25.0
# CUST0103    23.0
# CUST0104    40.0
# CUST0105    27.0
# CUST0106    50.0
# CUST0107    67.0
# CUST0108     NaN
# CUST0109    57.0
# CUST0111    19.0
# CUST0112    33.0
# CUST0113    38.0
# CUST0114    60.0
# CUST0115    53.0
# CUST0116    20.0
# CUST0117    22.0
# CUST0118    23.0
# CUST0120    35.0
# CUST0121    66.0
# CUST0122    68.0
# CUST0123    52.0
# CUST0124    53.0
# CUST0125    46.0
# CUST0126    66.0
# CUST0127    62.0
# CUST0128    52.0
# CUST0129    66.0
# CUST0130    68.0
# CUST0131    67.0
# CUST0133    47.0
# CUST0134    58.0
# CUST0135    41.0
# CUST0136    36.0
# CUST0137    19.0
# CUST0138    46.0
# CUST0139    57.0
# CUST0140    50.0
# CUST0141    58.0
# CUST0142    32.0
# CUST0143    36.0
# CUST0144    54.0
# CUST0145    51.0
# CUST0146    47.0
# CUST0147    64.0
# CUST0148    67.0
# CUST0149    40.0
# CUST0150    63.0
# CUST0152    69.0
# CUST0153    40.0
# CUST0154    31.0
# CUST0155    41.0
# CUST0156    57.0
# CUST0157    48.0
# CUST0158    51.0
# CUST0159    18.0
# CUST0160    69.0
# CUST0161    62.0
# CUST0162    69.0
# CUST0163    22.0
# CUST0164    50.0
# CUST0165    49.0
# CUST0166    29.0
# CUST0167    67.0
# CUST0168    42.0
# CUST0169    54.0
# CUST0170    40.0
# CUST0171    21.0
# CUST0172    56.0
# CUST0173    65.0
# CUST0174    68.0
# CUST0176    51.0
# CUST0177    29.0
# CUST0178    44.0
# CUST0179    45.0
# CUST0180    68.0
# CUST0181    59.0
# CUST0182    19.0
# CUST0183    42.0
# CUST0184    54.0
# CUST0185    29.0
# CUST0186    55.0
# CUST0187    25.0
# CUST0188    29.0
# CUST0189    38.0
# CUST0190    28.0
# CUST0191    41.0
# CUST0192    58.0
# CUST0193    64.0
# CUST0194    61.0
# CUST0195    48.0
# CUST0196    37.0
# CUST0197    54.0
# CUST0198    56.0
# CUST0199    41.0
# CUST0200    68.0
# CUST0201    49.0
# CUST0202    56.0
# CUST0203    33.0
# CUST0204    54.0
# CUST0205    43.0
# CUST0206    43.0
# CUST0207    54.0
# CUST0208    57.0
# CUST0209    63.0
# CUST0210    30.0
# CUST0211    35.0
# CUST0212    62.0
# CUST0213    45.0
# CUST0214    45.0
# CUST0215    35.0
# CUST0216    53.0
# CUST0217    18.0
# CUST0218    36.0
# CUST0219    48.0
# CUST0220    67.0
# CUST0221    33.0
# CUST0222    61.0
# CUST0223    20.0
# CUST0224    57.0
# CUST0225    65.0
# CUST0226    43.0
# CUST0227    54.0
# CUST0228    25.0
# CUST0229    45.0
# CUST0230     NaN
# CUST0231     NaN
# CUST0232    44.0
# CUST0233    24.0
# CUST0234    44.0
# CUST0235    19.0
# CUST0236    18.0
# CUST0237    65.0
# CUST0238    26.0
# CUST0239    35.0
# CUST0240    39.0
# CUST0241    27.0
# CUST0242    58.0
# CUST0243    58.0
# CUST0244    24.0
# CUST0245    63.0
# CUST0246    64.0
# CUST0247    44.0
# CUST0248    67.0
# CUST0249    33.0
# CUST0250    64.0
# CUST0251    42.0
# CUST0252    55.0
# CUST0253    51.0
# CUST0254     NaN
# CUST0255    39.0
# CUST0256    69.0
# CUST0257    54.0
# CUST0258    39.0
# CUST0259    59.0
# CUST0260    32.0
# CUST0261    48.0
# CUST0262    27.0
# CUST0263    40.0
# CUST0264    59.0
# CUST0265    38.0
# CUST0266    29.0
# CUST0267    29.0
# CUST0268    21.0
# CUST0269    64.0
# CUST0270    64.0
# CUST0271    46.0
# CUST0272    52.0
# CUST0273    55.0
# CUST0274    51.0
# CUST0276    66.0
# CUST0278    52.0
# CUST0279    59.0
# CUST0280    44.0
# CUST0281    44.0
# CUST0282    68.0
# CUST0283    67.0
# CUST0284    64.0
# CUST0285    58.0
# CUST0286    63.0
# CUST0287    60.0
# CUST0288    55.0
# CUST0289    37.0
# CUST0290    37.0
# CUST0291    49.0
# CUST0292    21.0
# CUST0293    32.0
# CUST0294    49.0
# CUST0295    26.0
# CUST0296    50.0
# CUST0297    61.0
# CUST0298    58.0
# CUST0299    58.0
# CUST0300    66.0
# Name: age, dtype: float64

# %%
df['age'] = df['age'].fillna(df['customer_id'].map(df.groupby('customer_id')['age'].apply(lambda x: x.mode()[0] if not x.mode().empty else None)))

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      1000 non-null   object
#  1   gender           1000 non-null   object
#  2   region           1000 non-null   object
#  3   age              993 non-null    float64
#  4   product_name     1000 non-null   object
#  5   category         1000 non-null   object
#  6   unit_price       1000 non-null   float64
#  7   quantity         1000 non-null   int64
#  8   total_price      1000 non-null   int64
#  9   shipping_fee     1000 non-null   float64
#  10  shipping_status  1000 non-null   object
#  11  order_date       1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(2), object(6)
# memory usage: 93.9+ KB

# %%
df.age = df.age.fillna(df.age.median())

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 12 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   customer_id      1000 non-null   object
#  1   gender           1000 non-null   object
#  2   region           1000 non-null   object
#  3   age              1000 non-null   float64
#  4   product_name     1000 non-null   object
#  5   category         1000 non-null   object
#  6   unit_price       1000 non-null   float64
#  7   quantity         1000 non-null   int64
#  8   total_price      1000 non-null   int64
#  9   shipping_fee     1000 non-null   float64
#  10  shipping_status  1000 non-null   object
#  11  order_date       1000 non-null   datetime64[ns]
# dtypes: datetime64[ns](1), float64(3), int64(2), object(6)
# memory usage: 93.9+ KB

# %% [markdown]
# <a id='data-visualization'></a>
# # <font color='firebrick'> <b>Data Visualization</b><font color='black'>

# %% [markdown]
# <a id='save-data'></a>
# # <font color='firebrick'> <b>Save to Dataset</b><font color='black'>

# %% [markdown]
# <p style="background-color:firebrick;font-family:newtimeroman;font-size:200%;color:white;text-align:center;border-radius:20px 20px;"><b>THANK YOU!</b></p>
